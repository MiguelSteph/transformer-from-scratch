# %% [markdown]
# # Data preprocessing
#
# During the data exploration, we noticed that the majority of the training samples have less than 100 tokens.
# In this notebook, we will preprocessed the data and save. The goal is to not perform any extra processing of the data during tokenization.

# %%
import os
import urllib.request
from urllib.error import HTTPError
from tokenizers import ByteLevelBPETokenizer
import time

# %%
# !mkdir tokenizer_32_000_vocab_size_model

# %%
base_url = "https://raw.githubusercontent.com/MiguelSteph/transformer-from-scratch/version2/"
def download_file_from_github(file_path: str, file_name: str):
    if not os.path.isfile(file_name):
        file_url = base_url + file_path
        print(f"Downloading {file_url}...")
        try:
            urllib.request.urlretrieve(file_url, file_name)
        except HTTPError as e:
            print("Something went wrong. Please try to download the file directly from the GitHub repository:\n", e)

file_paths = [
    'configs/configs.py',
    'data/tokenizer.py',
    'data/data.py',
    'data/tokenizer_32_000_vocab_size_model/merges.txt',
    'data/tokenizer_32_000_vocab_size_model/vocab.json',
]
file_names = [
    'configs.py',
    'tokenizer.py',
    'data.py',
    'tokenizer_32_000_vocab_size_model/merges.txt',
    'tokenizer_32_000_vocab_size_model/vocab.json',
]

for file_path, file_name in zip(file_paths, file_names): 
    download_file_from_github(file_path, file_name)
# Out:
# Downloading https://raw.githubusercontent.com/MiguelSteph/transformer-from-scratch/version2/configs/configs.py...
# Downloading https://raw.githubusercontent.com/MiguelSteph/transformer-from-scratch/version2/data/tokenizer.py...
# Downloading https://raw.githubusercontent.com/MiguelSteph/transformer-from-scratch/version2/data/data.py...
# Downloading https://raw.githubusercontent.com/MiguelSteph/transformer-from-scratch/version2/data/tokenizer_32_000_vocab_size_model/merges.txt...
# Downloading https://raw.githubusercontent.com/MiguelSteph/transformer-from-scratch/version2/data/tokenizer_32_000_vocab_size_model/vocab.json...

# %%
from configs import get_configs
from data import preprocessed_and_saved_dataset, download_and_get_raw_datasets
# Out:
# 2026-04-26 20:43:51.716325: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777236231.965908      16 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777236232.044294      16 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777236232.649752      16 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777236232.649801      16 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777236232.649804      16 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777236232.649807      16 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
config = get_configs()
de_tokenizer = ByteLevelBPETokenizer(config.data.de_tokenizer_model_path + '/vocab.json',
                                     config.data.de_tokenizer_model_path + '/merges.txt')
de_tokenizer.add_special_tokens(list(config.data.special_tokens))
en_tokenizer = ByteLevelBPETokenizer(config.data.en_tokenizer_model_path + '/vocab.json',
                                     config.data.en_tokenizer_model_path + '/merges.txt')
en_tokenizer.add_special_tokens(list(config.data.special_tokens))

train_ds, validation_ds, test_ds = download_and_get_raw_datasets()
# Out:
# WARNING:absl:Using custom data configuration: WmtConfig(name='de-en', version='1.0.0', release_notes=None, supported_versions=[], description=None, tags=[])
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/wmt_translate/de-en/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/wmt_translate/de-en/incomplete.FF9I65_1.0.0/wmt_translate-train.tfrecord*.…
# Generating validation examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/wmt_translate/de-en/incomplete.FF9I65_1.0.0/wmt_translate-validation.tfrec…
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/wmt_translate/de-en/incomplete.FF9I65_1.0.0/wmt_translate-test.tfrecord*..…
# Dataset wmt_translate downloaded and prepared to /root/tensorflow_datasets/wmt_translate/de-en/1.0.0. Subsequent calls will reuse this data.
# 2026-04-26 20:52:40.677363: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
# Run this to preprocessed a small part of the dataset mainly for testing and profiling purpose
# train_ds = train_ds.take(10_000)

# %%
start_time = time.time()
preprocessed_and_saved_dataset(de_tokenizer,
                               en_tokenizer,
                               train_ds,
                               config.data.train_ds_path,
                               config.data.max_seq_len)
print(f"Preprocessing the training data takes {time.time() - start_time} seconds")


start_time = time.time()
preprocessed_and_saved_dataset(de_tokenizer,
                               en_tokenizer,
                               validation_ds,
                               config.data.validation_ds_path,
                               config.data.max_seq_len)
print(f"Preprocessing the validation data takes {time.time() - start_time} seconds")


start_time = time.time()
preprocessed_and_saved_dataset(de_tokenizer,
                               en_tokenizer,
                               test_ds,
                               config.data.test_ds_path,
                               config.data.max_seq_len)
print(f"Preprocessing the test data takes {time.time() - start_time} seconds")
# Out:
# Preprocessing the training data takes 971.9687175750732 seconds
# Preprocessing the validation data takes 6.631864547729492 seconds
# Preprocessing the test data takes 1.7946276664733887 seconds

# %%
# !zip -r preprocessed_data.zip preprocessed_data
# Out:
#   adding: preprocessed_data/ (stored 0%)
#   adding: preprocessed_data/train.tfrecord (deflated 0%)
#   adding: preprocessed_data/test.tfrecord (deflated 0%)
#   adding: preprocessed_data/validation.tfrecord (deflated 0%)
